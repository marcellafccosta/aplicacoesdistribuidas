// %% [markdown]
// # Exercise 1

// %% [markdown]
// 1. **Execute o código abaixo em um arquivo cpp da seguinte maneira**:
//
//     * Na pasta ompenmp/notebooks/codigo_externo, crie um aquivo chamado:
//         * "exercise_1.cpp".
//
//     * Clique duas vezes para abrí-lo no editor do VSCode.
//
//     * Copie e cole o código abaixo dentro do arquivo e salve.
//
//     * No terminal Linux, vá até a pasta do aquivo:
//         * cd ompenmp/notebooks/codigo_externo
//
//     * Compile o aquivo:
//         * g++ -fopenmp exercise_1.cpp -o exercise_1.exe
//
//     * Execute o programa:
//         ./exercise_1.exe
//
// 2. **Execute o código no notebook (single thread) e depois fora do notebook (número de threads == número de núcleos).**
//     * Insira o código necessário para iniciar a contagem do tempo antes do paralelismo
//     * Insira o código necessário para calcular o tempo corrigo após o término do paralelismo
//     * Faça 3 execuções do código fora do notebook e, para cada uma, faça:
//         * **Varie o valor de "n" e o número de threads**
//         * Imprima os resultados no console
//         * Copie o tempo para a célula do tipo markdown que se encontra abaixo da célula de código
//     * Compare e comente a variação nos tempos.
//
// 3. **Volte a este notebook**:
//     * Na célula do tipo markdown abaixo da célula que contém o código a ser executado.
//
// **Obs: dentro do notebook é executada apenas uma thread. Por isso, execute fora do notebook para ver o paralelismo.**

// %% [markdown]
// O seguinte código executa duas operações sobre os arrays a e b:

// %%
#include "notebooks_reserved_code/openmp_config.h"
#include <omp.h>
#include <stdio.h>
#include <stdlib.h>


int main()
{
	int n = 5000;
	int i, nthreads, tid;
	float a[n], b[n], c[n], d[n];
	double start_time, end_time;

	/* Some initializations */
	for(i=0; i<n; i++){
	  a[i] = i * 1.5;
	  b[i] = i + 22.35;
	  c[i] = d[i] = 0.0;
	 }


	 start_time = omp_get_wtime();
	/*1 - O QUE ESTÁ ACONCENDO AQUI?*/
	#pragma omp parallel shared(a,b,c,d,nthreads) private(i,tid)
	{
		tid = omp_get_thread_num();
		/*2 - O QUE ESTÁ ACONCENDO AQUI?*/
		if(tid == 0)
		{
			nthreads = omp_get_num_threads();
			printf("Number of threads = %d\n", nthreads);
		}
		printf("Thread %d starting...\n",tid);
		
		/*3 - O QUE ESTÁ ACONCENDO AQUI?*/
		#pragma omp sections nowait
		{
			/*4 - O QUE ESTÁ ACONCENDO AQUI?*/
			#pragma omp section
			{
			  printf("Thread %d doing section 1\n",tid);
			  for(i=0; i<n; i++){
				  c[i] = a[i] + b[i];
				  printf("Thread %d: c[%d]= %f\n",tid,i,c[i]);
				}
			}
			/*5 - O QUE ESTÁ ACONCENDO AQUI?*/
			#pragma omp section
			{
			  printf("Thread %d doing section 2\n",tid);
			  for(i=0; i<n; i++){
				  d[i] = a[i] * b[i];
				  printf("Thread %d: d[%d]= %f\n",tid,i,d[i]);
				}
			}

		} 

		printf("Thread %d done.\n",tid); 
		

	}  
	end_time = omp_get_wtime();
	printf("Time taken: %f seconds\n", end_time - start_time);
	

}
main()
// Out:
// Number of threads = 1
// Thread 0 starting...
// Thread 0 doing section 1
// Thread 0: c[0]= 22.350000
// Thread 0: c[1]= 24.850000
// Thread 0: c[2]= 27.350000
// Thread 0: c[3]= 29.850000
// Thread 0: c[4]= 32.349998
// Thread 0: c[5]= 34.849998
// Thread 0: c[6]= 37.349998
// Thread 0: c[7]= 39.849998
// Thread 0: c[8]= 42.349998
// Thread 0: c[9]= 44.849998
// Thread 0: c[10]= 47.349998
// Thread 0: c[11]= 49.849998
// Thread 0: c[12]= 52.349998
// Thread 0: c[13]= 54.849998
// Thread 0: c[14]= 57.349998
// Thread 0: c[15]= 59.849998
// Thread 0: c[16]= 62.349998
// Thread 0: c[17]= 64.849998
// Thread 0: c[18]= 67.349998
// Thread 0: c[19]= 69.849998
// Thread 0: c[20]= 72.349998
// Thread 0: c[21]= 74.849998
// Thread 0: c[22]= 77.349998
// Thread 0: c[23]= 79.849998
// Thread 0: c[24]= 82.349998
// Thread 0: c[25]= 84.849998
// Thread 0: c[26]= 87.349998
// Thread 0: c[27]= 89.849998
// Thread 0: c[28]= 92.349998
// Thread 0: c[29]= 94.849998
// Thread 0: c[30]= 97.349998
// ...

// %% [markdown]
// ## Resultados:
// **Obs: após editar uma célula do tipo markdown, é preciso pressionar as tecla CTRL+ENTER para renderizar o texto**
//
//
// 1. Coloque aqui as variações nos tempos de execução para cada variação de "n" e comente o que você obervou com base na matéria estudada e nos materiais de referência.
//
// | Valor de `n` | Tempo (single-thread) | Tempo (multi-thread) |
// |--------------|-----------------------|----------------------|
// | 50           | 0.000208              | 0.006981             |
// | 500          | 0.001805              | 0.018742             |
// | 5000         | 0.016758              | 0.215441             |
//
//
// #### n = 50 (Single-thread)
// ![n=50 single-thread](images/ex1/single50.png)
//
// ---
//
// #### n = 50 (Multi-thread)
// ![n=50 multi-thread](images/ex1/multi50.png)
//
// ---
//
// #### n = 500 (Single-thread)
// ![n=500 single-thread](images/ex1/single500.png)
//
// ---
//
// #### n = 500 (Multi-thread)
// ![n=500 multi-thread](images/ex1/multi500.png)
//
// ---
//
// #### n = 5000 (Single-thread)
// ![n=5000 single-thread](images/ex1/single5000.png)
//
// ---
//
// #### n = 5000 (Multi-thread)
// ![n=5000 multi-thread](images/ex1/multi5000.png)
//
//
// Com base nos dados, observa-se que o uso de múltiplas threads aumentou o tempo de execução em todas as variações de n. Isso ocorre porque, apesar de o paralelismo prometer melhor desempenho, ele também adiciona sobrecarga. Nos valores mais baixos de n, essa sobrecarga é mais perceptível e supera qualquer ganho possível. Já em n = 5000, esperava-se um ganho com múltiplas threads, mas o tempo foi maior, indicando que o tipo de paralelismo usado (com sections) não escalou bem para o problema. Isso reforça que o paralelismo só é vantajoso quando o custo de dividir e gerenciar as tarefas é compensado pelo tamanho da carga de trabalho. Além disso, o uso de sections ao invés de parallel for pode ter causado desequilíbrio na divisão das tarefas, prejudicando o desempenho.
//
// 2. Observe que, no código, há comentários numerados, como este: /*1 - O QUE ESTÁ ACONCENDO AQUI?*/. Para cada comentário, explique abaixo o que está acontecendo no respectivo código ao qual o comentário se refere.
//
//     a. Comentário 1:
// Está sendo criado um ambiente de paralelismo com a diretiva #pragma omp parallel. Todas as instruções do bloco serão executadas por múltiplas threads simultaneamente. Tem variáveis shared (a, b, c, d, nthreads), que são acessada por todos, e variáveis private (i, tid), que são uma cópia individual por thread.
//
//
//     b. Comentário 2:
// A thread executando este trecho obtém seu identificador com omp_get_thread_num(), e se for a thread de ID 0 (geralmente a principal), ela armazena na variável nthreads o número total de threads criadas com omp_get_num_threads(), e imprime esse valor na tela.
//
//
//     c. Comentário 3:
// Está utilizando a diretiva #pragma omp sections nowait, que permite que diferentes threads executem blocos de código independentes ao mesmo tempo. Cada seção é atribuída a uma thread disponível, otimizando a execução paralela. O nowait evita que as threads esperem umas pelas outras ao final das seções.
//
//     d. Comentário 4:
// Nessa seção, uma das threads executa a soma dos vetores `a` e `b`, armazenando o resultado em `c`.
//
//
//     e. Comentário 5:
// Nessa seção, uma das threads executa a multiplicação dos vetores `a` e `b`, armazenando o resultado em `d`.

// %% [markdown]
// ## Entrega:
//
// **Salve este notebook com as suas respostas e poste como entrega da atividade no Canvas.**
